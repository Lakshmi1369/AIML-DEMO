# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)
plt.title("Line Chart")
plt.ylabel('Y-Axis')
plt.xlabel('X-Axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 x = [10, 20, 30, 40]
#       4 y = [20, 25, 35, 55]
#
# File c:\Users\HP\.anaconda3\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Users\HP\.anaconda3\Lib\site-packages\matplotlib\cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# ...
